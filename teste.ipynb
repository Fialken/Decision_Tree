# %%
import pandas as pd
df = pd.read_csv("datasets/weather.csv")
df_X = pd.read_csv("datasets/weather.csv")

# %%
pred = df["Play"]
df.drop(columns='Play',inplace=True)
df_X.drop(columns='Play',inplace=True)
try:
    df.drop(columns='ID',inplace=True)
    df_X.drop(columns='ID',inplace=True)
except:
    ...

    
df
# Out:
#      Weather  Temp  Humidity  Windy
# 0      sunny    85        85  False
# 1      sunny    80        90   True
# 2   overcast    83        86  False
# 3      rainy    70        96  False
# 4      rainy    68        80  False
# 5      rainy    65        70   True
# 6   overcast    64        65   True
# 7      sunny    72        95  False
# 8      sunny    69        70  False
# 9      rainy    75        80  False
# 10     sunny    75        70   True
# 11  overcast    72        90   True
# 12  overcast    81        75  False
# 13     rainy    71        91   True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import KBinsDiscretizer
import pandas as pd

est = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
df = pd.read_csv("datasets/weather.csv")

for attrib in df.columns:
    if ... : #condicao quando os dados sao numericos para serem discretizados
        df[attrib] = pd.DataFrame(est.fit_transform(df[attrib].to_frame()),columns=[attrib])
