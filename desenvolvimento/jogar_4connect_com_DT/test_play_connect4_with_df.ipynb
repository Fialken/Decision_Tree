# %%
import joblib
decision_tree = joblib.load('arvore_4connected.pkl')

# %%
from Game4InLine import Game4InLine as G4Line

tabu = [[["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["x","x","b","b","x","b","b"],
          ["o","x","o","b","o","b","b"]],

        [["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","o","b","b","b","b"],
          ["b","o","o","b","b","b","b"],
          ["b","x","x","x","b","b","x"]],

        [["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","x","b","b","b","b"],
          ["b","b","o","b","x","b","b"],
          ["b","b","x","b","o","o","o"]],

        [["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","x","o","b","b","b"],
          ["b","b","o","b","x","b","x"]],

        [["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","b","b","b","b","b"],
          ["b","b","o","b","b","x","b"],
          ["b","x","x","x","o","o","b"]]]
game=G4Line(6,7)
for boards in tabu:
    game.board = boards
    game.resultado_DT()
    print()
# Out:
# Colunas que originam "wins": []
# Colunas que originam "draws": [0, 1, 2, 3, 4, 5, 6]
#  Colunas que originam "loses": []
#
# Colunas que originam "wins": []
# Colunas que originam "draws": []
#  Colunas que originam "loses": [0, 1, 2, 3, 4, 5, 6]
#
# Colunas que originam "wins": [0, 1, 2, 3, 4, 5, 6]
# Colunas que originam "draws": []
#  Colunas que originam "loses": []
#
# Colunas que originam "wins": [0, 1, 2, 3, 4, 5, 6]
# Colunas que originam "draws": []
#  Colunas que originam "loses": []
#
# Colunas que originam "wins": []
# Colunas que originam "draws": []
#  Colunas que originam "loses": [0, 1, 2, 3, 4, 5, 6]

# %%
from Game4InLine import Game4InLine as G4Line
import random
game=G4Line(6,7)
def gerar_7(game):
    for i in range(7):
        legal  = game.legal_moves()
        game.play(random.choice(legal))

for i in range(5):
    game=G4Line(6,7)
    gerar_7(game)
    print(game)
    game.resultado_DT()

# %%
for i in range(5):
    game=G4Line(6,7)
    gerar_7(game)
    print(game)
    game.resultado_DT()
    print()
# Out:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | o | - | x | - | - |
# | - | x | x | x | o | - | o |
#
# Colunas que originam "wins": []
# Colunas que originam "draws": []
#  Colunas que originam "loses": [0, 1, 2, 3, 4, 5, 6]
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | o | - | - | - | - |
# | - | o | o | - | - | - | - |
# | - | x | x | x | - | - | x |
#
# Colunas que originam "wins": []
# Colunas que originam "draws": []
#  Colunas que originam "loses": [0, 1, 2, 3, 4, 5, 6]
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | x | x | - | - | x | - | - |
# | o | x | o | - | o | - | - |
#
# Colunas que originam "wins": []
# Colunas que originam "draws": [0, 1, 2, 3, 4, 5, 6]
#  Colunas que originam "loses": []
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | x | x | - | - |
# | - | o | - | o | o | x | x |
#
# Colunas que originam "wins": [0, 1, 2, 3, 4, 5, 6]
# Colunas que originam "draws": []
#  Colunas que originam "loses": []
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | o | - | - | x | - |
# | - | x | x | x | o | o | - |
#
# Colunas que originam "wins": []
# Colunas que originam "draws": []
#  Colunas que originam "loses": [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# Testar 4connect A* heuristica vs DT

# %%
from Game4InLine import Game4InLine as G4Line
def result(game,col):
    ''' 
    funcao para analisar quando o jogo acabar se foi empate ou qual jogador ganhou
    '''
    res=game.isFinished(col)
    if res:
        if res==2:
            print(f"Draw")
        else:
            print(f"{game.pieces[game.turn-1]} won")
        return True
    return False

def main_A_star():
    '''
    this function was created to play A* vs A* without any human interaction
    as we have no variations to play, we will always play the same game/result
    and player 2 (O) is the winner all the time with 30 rounds played
    '''
    game=G4Line(6,7) #board is set to 'normal' size
    #main loop
    while True:     
        #A* with DT
        print(f"A* DT ('{game.pieces[game.turn%2]}') turn") # to know which turn is X(1) or O(2)
        #play 
        column_played=game.A_star(1)
        game.play(column_played)
        print(f"played: {column_played+1}")
        print(f"Board:\n{game}")

        if result(game,column_played):
            break

        
        #A* normal
        print(f"A* heuristic ('{game.pieces[game.turn%2]}') turn") # to know which turn is X(1) or O(2)
        #play 
        column_played=game.A_star(0)
        game.play(column_played)
        print(f"played: {column_played+1}")
        print(f"Board:\n{game}")

        if result(game,column_played):
            break
        
    print(f"game took {game.round} rounds")

# %%
main_A_star()
# Out:
# A* DT ('x') turn
# wining cols: [0, 1, 2, 3, 4, 5, 6]
# played: 6
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | x | - |
#
# A* heuristic ('o') turn
# played: 4
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | o | - | x | - |
#
# A* DT ('x') turn
# wining cols: [0, 1, 2, 3, 4, 5, 6]
# played: 6
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | x | - |
# | - | - | - | o | - | x | - |
#
# A* heuristic ('o') turn
# played: 6
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | o | - |
# | - | - | - | - | - | x | - |
# | - | - | - | o | - | x | - |
#
# A* DT ('x') turn
# wining cols: [0, 1, 2, 3, 4, 5, 6]
# played: 1
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | o | - |
# | - | - | - | - | - | x | - |
# | x | - | - | o | - | x | - |
#
# A* heuristic ('o') turn
# played: 4
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | o | - |
# | - | - | - | o | - | x | - |
# | x | - | - | o | - | x | - |
#
# A* DT ('x') turn
# wining cols: [0, 1, 2, 3, 4, 5, 6]
# played: 7
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | o | - |
# | - | - | - | o | - | x | - |
# | x | - | - | o | - | x | x |
#
# A* heuristic ('o') turn
# played: 4
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | o | - | o | - |
# | - | - | - | o | - | x | - |
# | x | - | - | o | - | x | x |
#
# A* DT ('x') turn
# wining cols: [0, 1, 2, 3, 4, 5, 6]
# played: 6
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | x | - |
# | - | - | - | o | - | o | - |
# | - | - | - | o | - | x | - |
# | x | - | - | o | - | x | x |
#
# A* heuristic ('o') turn
# played: 4
# Board:
# | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
# | - | - | - | - | - | - | - |
# | - | - | - | - | - | - | - |
# | - | - | - | o | - | x | - |
# | - | - | - | o | - | o | - |
# | - | - | - | o | - | x | - |
# | x | - | - | o | - | x | x |
#
# o won
# game took 10 rounds
